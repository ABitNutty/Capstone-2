# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import pickle
from wordcloud import WordCloud

# %%
# Load in dictionaries of word importance
importance = pickle.load( open( "log_reg_influential_words.pickle", "rb" ) )

# %%
importance
# Out:
# {'Good': {'also': 4736,
#   'reasonably': 53694,
#   'exceeded': 23986,
#   'fabulous': 24488,
#   'little': 38828,
#   'notch': 45507,
#   'heaven': 31430,
#   'nice': 44727,
#   'superb': 63776,
#   'yum': 73765,
#   'tasty': 65059,
#   'recommend': 53874,
#   'well': 71620,
#   'vegas': 69970,
#   'reasonable': 53689,
#   'bomb': 9876,
#   'thank': 65765,
#   'disappoint': 20471,
#   'glad': 28785,
#   'delish': 19430,
#   'pleasantly': 50597,
#   'outstanding': 47398,
#   'everything': 23899,
#   'enjoyed': 23213,
#   'die': 20092,
#   'phenomenal': 49625,
#   'fresh': 27168,
#   'happy': 30969,
#   'yummy': 73809,
#   'friendly': 27292,
#   'always': 4788,
#   'incredible': 33866,
#   'perfection': 49298,
#   'highly': 31898,
#   'gem': 28344,
#   'perfectly': 49308,
#   'loved': 39400,
#   'wonderful': 72667,
#   'favorite': 24993,
#   'definitely': 19219,
#   'good': 29159,
#   'fantastic': 24765,
#   'perfect': 49290,
#   'love': 39393,
#   'awesome': 6842,
#   'best': 8770,
# ...

# %%
# Create the wordcloud object
goodcloud = WordCloud(width=2048, height=2048, margin=0, background_color="white").generate_from_frequencies(importance['Good'])

badcloud = WordCloud(width=2048, height=2048, margin=0, background_color="white").generate_from_frequencies(importance['Bad'])

# %%
# Display the generated image:
plt.imshow(goodcloud, interpolation='bilinear')
plt.axis("off")
plt.title('Good Reviews')
plt.show()

# %%
# Display the generated image:
plt.imshow(badcloud, interpolation='bilinear')
plt.axis("off")
plt.title('Bad Reviews')
plt.show()

# %%
# Load in dictionaries of word importance
importance = pickle.load( open( "log_reg_influential_words_bigrams.pickle", "rb" ) )

# %%
# Create the wordcloud object
goodcloud = WordCloud(width=2048, height=2048, margin=0, background_color="white").generate_from_frequencies(importance['Good'])

badcloud = WordCloud(width=2048, height=2048, margin=0, background_color="white").generate_from_frequencies(importance['Bad'])

# %%
# Display the generated image:
plt.imshow(goodcloud, interpolation='bilinear')
plt.axis("off")
plt.title('Good Reviews')
plt.show()

# %%
# Display the generated image:
plt.imshow(badcloud, interpolation='bilinear')
plt.axis("off")
plt.title('Bad Reviews')
plt.show()
